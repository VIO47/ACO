# %%
import time

from AntColonyOptimization import AntColonyOptimization
from GeneticAlgorithm import GeneticAlgorithm
from Maze import Maze
from PathSpecification import PathSpecification
from TSPData import TSPData

# %% [markdown]
# ### Part 1: The Travelling Robot Problem

# %%
# Please keep your parameters for the Genetic Algorithm easily changeable here
population_size = 20
generations = 20
persist_file = "./../data/optimal_tsp"

# Setup optimization
tsp_data = TSPData.read_from_file(persist_file)
ga = GeneticAlgorithm(generations, population_size)

# Run optimzation and write to file
solution = ga.solve_tsp(tsp_data)
tsp_data.write_action_file(solution, "./../data/tsp_solution.txt")

# %% [markdown]
# ### Part 2: Path Finding Through Ant Colony Optimization

# %%
# Please keep your parameters for the ACO easily changeable here
gen = 1
no_gen = 1
q = 1600
evap = 0.1

# Construct the optimization objects
maze = Maze.create_maze("./../data/hard_maze.txt")
spec = PathSpecification.read_coordinates("./../data/hard_coordinates.txt")
aco = AntColonyOptimization(maze, gen, no_gen, q, evap)

# Save starting time
start_time = int(round(time.time() * 1000))

# Run optimization
shortest_route = aco.find_shortest_route(spec)

# Print time taken
print("Time taken: " + str((int(round(time.time() * 1000)) - start_time) / 1000.0))

# Save solution
shortest_route.write_to_file("./../data/hard_solution.txt")

# Print route size
print("Route size: " + str(shortest_route.size()))
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Found route of length 1167
# Found route of length 1185
# Found route of length 1335
# Found route of length 1179
# Found route of length 1123
# Found route of length 1515
# Found route of length 1151
# Found route of length 1137
# Found route of length 1035
# Found route of length 1175
# Found route of length 1215
# Found route of length 1255
# Found route of length 1099
# Found route of length 1165
# Found route of length 1247
# Found route of length 1305
# Found route of length 1203
# Found route of length 1053
# Found route of length 1161
# Found route of length 1227
# Found route of length 1009
# Found route of length 1155
# Found route of length 1119
# Found route of length 1081
# Found route of length 1059
# Found route of length 1373
# Found route of length 1145
# Found route of length 1381
# Found route of length 1083
# Found route of length 1267
# Time taken: 2.027
# Route size: 1009

# %% [markdown]
# ### Synthesis

# %%
# Please keep your parameters for the synthesis part easily changeable here
gen = 1
no_gen = 1
q = 1000
evap = 0.1

persist_file = "./../tmp/my_tsp"
tsp_path = "./../data/tsp_products.txt"
coordinates = "./../data/hard_coordinates.txt"

# Construct optimization
maze = Maze.create_maze("./../data/hard_maze.txt")
tsp_data = TSPData.read_specification(coordinates, tsp_path)
aco = AntColonyOptimization(maze, gen, no_gen, q, evap)

# Run optimization and write to file
tsp_data.calculate_routes(aco)
tsp_data.write_to_file(persist_file)

# Read from file and print
tsp_data2 = TSPData.read_from_file(persist_file)
print(tsp_data == tsp_data2)

# Solve TSP using your own paths file
ga = GeneticAlgorithm(generations, population_size)
solution = ga.solve_tsp(tsp_data2)
tsp_data2.write_action_file(solution, "./../data/tsp_solution.txt")
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 0
# Found route of length 129
# Found route of length 147
# Found route of length 131
# Found route of length 87
# Found route of length 143
# Found route of length 125
# Found route of length 97
# Found route of length 129
# Found route of length 107
# Found route of length 85
# Found route of length 97
# Found route of length 101
# Found route of length 85
# Found route of length 91
# Found route of length 135
# Found route of length 129
# Found route of length 129
# Found route of length 83
# Found route of length 87
# Found route of length 93
# Found route of length 93
# Found route of length 153
# Found route of length 111
# Found route of length 81
# Found route of length 93
# Found route of length 95
# Found route of length 91
# Found route of length 83
# Found route of length 95
# Found route of length 127
# Found route of length 123
# Found route of length 85
# Found route of length 105
# Found route of length 123
# Found route of length 83
# Found route of length 85
# Found route of length 83
# Found route of length 93
# Found route of length 125
# Found route of length 73
# Found route of length 77
# Found route of length 81
# Found route of length 101
# Found route of length 85
# Found route of length 145
# Found route of length 119
# Found route of length 117
# Found route of length 137
# Found route of length 133
# Found route of length 109
# Found route of length 99
# Found route of length 101
# Found route of length 97
# Found route of length 87
# Found route of length 85
# Found route of length 111
# Found route of length 105
# Found route of length 91
# Found route of length 121
# Found route of length 137
# Found route of length 91
# Found route of length 97
# Found route of length 85
# Found route of length 91
# Found route of length 77
# Found route of length 77
# Found route of length 87
# Found route of length 77
# Found route of length 73
# Found route of length 105
# Found route of length 81
# Found route of length 85
# Found route of length 139
# Found route of length 133
# Found route of length 73
# Found route of length 99
# Found route of length 75
# Found route of length 101
# Found route of length 89
# Found route of length 85
# Found route of length 101
# Found route of length 119
# Found route of length 89
# Found route of length 97
# Found route of length 131
# Found route of length 77
# Found route of length 117
# Found route of length 79
# Found route of length 89
# Found route of length 111
# Found route of length 121
# Found route of length 83
# Found route of length 97
# Found route of length 73
# Found route of length 77
# Found route of length 107
# Found route of length 137
# Found route of length 85
# Found route of length 131
# Found route of length 101
# Found route of length 135
# Found route of length 89
# Found route of length 93
# Found route of length 85
# Found route of length 81
# Found route of length 141
# Found route of length 105
# Found route of length 89
# Found route of length 109
# Found route of length 89
# Found route of length 139
# Found route of length 85
# Found route of length 111
# Found route of length 85
# Found route of length 81
# Found route of length 143
# Found route of length 107
# Found route of length 127
# Found route of length 101
# Found route of length 83
# Found route of length 119
# Found route of length 73
# Found route of length 85
# Found route of length 125
# Found route of length 89
# Found route of length 85
# Found route of length 101
# Found route of length 93
# Found route of length 85
# Found route of length 97
# Found route of length 101
# Found route of length 97
# Found route of length 127
# Found route of length 77
# Found route of length 79
# Found route of length 115
# Found route of length 123
# Found route of length 93
# Found route of length 85
# Found route of length 73
# Found route of length 85
# Found route of length 77
# Found route of length 127
# Found route of length 91
# Found route of length 131
# Found route of length 95
# Found route of length 75
# Found route of length 81
# Found route of length 103
# Found route of length 113
# Found route of length 91
# Found route of length 103
# Found route of length 85
# Found route of length 83
# Found route of length 113
# Found route of length 105
# Found route of length 121
# Found route of length 113
# Found route of length 81
# Found route of length 119
# Found route of length 113
# Found route of length 113
# Found route of length 77
# Found route of length 77
# Found route of length 93
# Found route of length 89
# Found route of length 135
# Found route of length 95
# Found route of length 125
# Found route of length 119
# Found route of length 79
# Found route of length 85
# Found route of length 109
# Found route of length 79
# Found route of length 119
# Found route of length 89
# Found route of length 119
# Found route of length 111
# Found route of length 115
# Found route of length 129
# Found route of length 89
# Found route of length 107
# Found route of length 99
# Found route of length 75
# Found route of length 95
# Found route of length 79
# Found route of length 89
# Found route of length 85
# Found route of length 77
# Found route of length 121
# Found route of length 91
# Found route of length 89
# Found route of length 139
# Found route of length 93
# Found route of length 71
# Found route of length 111
# Found route of length 93
# Found route of length 73
# Found route of length 107
# Found route of length 109
# Found route of length 79
# Found route of length 119
# Found route of length 95
# Found route of length 109
# Found route of length 131
# Found route of length 137
# Found route of length 83
# Found route of length 75
# Found route of length 93
# Found route of length 113
# Found route of length 89
# Found route of length 111
# Found route of length 129
# Found route of length 137
# Found route of length 77
# Found route of length 113
# Found route of length 129
# Found route of length 77
# Found route of length 75
# Found route of length 117
# Found route of length 73
# Found route of length 85
# Found route of length 101
# Found route of length 81
# Found route of length 73
# Found route of length 77
# Found route of length 121
# Found route of length 125
# Found route of length 97
# Found route of length 121
# Found route of length 129
# Found route of length 93
# Found route of length 77
# Found route of length 133
# Found route of length 107
# Found route of length 73
# Found route of length 89
# Found route of length 119
# Found route of length 77
# Found route of length 103
# Found route of length 93
# Found route of length 117
# Found route of length 77
# Found route of length 105
# Found route of length 83
# Found route of length 89
# Found route of length 109
# Found route of length 79
# Found route of length 97
# Found route of length 109
# Found route of length 73
# Found route of length 91
# Found route of length 83
# Found route of length 109
# Found route of length 73
# Found route of length 117
# Found route of length 109
# Found route of length 95
# Found route of length 73
# Found route of length 71
# Found route of length 105
# Found route of length 111
# Found route of length 73
# Found route of length 117
# Found route of length 121
# Found route of length 107
# Found route of length 105
# Found route of length 107
# Found route of length 75
# Found route of length 119
# Found route of length 119
# Found route of length 83
# Found route of length 89
# Found route of length 119
# Found route of length 85
# Found route of length 81
# Found route of length 85
# Found route of length 77
# Found route of length 71
# Found route of length 111
# Found route of length 93
# Found route of length 125
# Found route of length 85
# Found route of length 135
# Found route of length 113
# Found route of length 99
# Found route of length 113
# Found route of length 75
# Found route of length 91
# Found route of length 113
# Found route of length 113
# Found route of length 93
# Found route of length 111
# Found route of length 109
# Found route of length 115
# Found route of length 85
# Found route of length 99
# Found route of length 75
# Found route of length 119
# Found route of length 89
# Found route of length 107
# Found route of length 103
# Found route of length 77
# Found route of length 85
# Found route of length 83
# Found route of length 115
# Found route of length 111
# Found route of length 135
# Found route of length 93
# Found route of length 123
# Found route of length 129
# Found route of length 95
# Found route of length 73
# Found route of length 83
# Found route of length 85
# Found route of length 83
# Found route of length 73
# Found route of length 77
# Found route of length 143
# Found route of length 71
# Found route of length 119
# Found route of length 107
# Found route of length 83
# Found route of length 85
# Found route of length 79
# Found route of length 77
# Found route of length 117
# Found route of length 121
# Found route of length 137
# Found route of length 103
# Found route of length 73
# Found route of length 77
# Found route of length 83
# Found route of length 133
# Found route of length 109
# Found route of length 71
# Found route of length 137
# Found route of length 83
# Found route of length 79
# Found route of length 123
# Found route of length 113
# Found route of length 121
# Found route of length 113
# Found route of length 95
# Found route of length 81
# Found route of length 101
# Found route of length 113
# Found route of length 105
# Found route of length 77
# Found route of length 93
# Found route of length 127
# Found route of length 111
# Found route of length 85
# Found route of length 123
# Found route of length 77
# Found route of length 93
# Found route of length 127
# Found route of length 125
# Found route of length 83
# Found route of length 73
# Found route of length 81
# Found route of length 121
# Found route of length 103
# Found route of length 85
# Found route of length 109
# Found route of length 79
# Found route of length 91
# Found route of length 77
# Found route of length 109
# Found route of length 103
# Found route of length 97
# Found route of length 109
# Found route of length 113
# Found route of length 115
# Found route of length 73
# Found route of length 85
# Found route of length 123
# Found route of length 83
# Found route of length 103
# Found route of length 101
# Found route of length 133
# Found route of length 89
# Found route of length 123
# Found route of length 109
# Found route of length 97
# Found route of length 85
# Found route of length 89
# Found route of length 127
# Found route of length 83
# Found route of length 79
# Found route of length 111
# Found route of length 71
# Found route of length 89
# Found route of length 79
# Found route of length 89
# Found route of length 109
# Found route of length 103
# Found route of length 95
# Found route of length 89
# Found route of length 93
# Found route of length 93
# Found route of length 79
# Found route of length 71
# Found route of length 93
# Found route of length 85
# Found route of length 115
# Found route of length 79
# Found route of length 109
# Found route of length 83
# Found route of length 83
# Found route of length 99
# Found route of length 75
# Found route of length 89
# Found route of length 79
# Found route of length 85
# Found route of length 113
# Found route of length 73
# Found route of length 107
# Found route of length 79
# Found route of length 77
# Found route of length 93
# Found route of length 125
# Found route of length 73
# Found route of length 79
# Found route of length 85
# Found route of length 79
# Found route of length 79
# Found route of length 115
# Found route of length 123
# Found route of length 123
# Found route of length 97
# Found route of length 75
# Found route of length 109
# Found route of length 85
# Found route of length 115
# Found route of length 101
# Found route of length 71
# Found route of length 83
# Found route of length 99
# Found route of length 85
# Found route of length 81
# Found route of length 85
# Found route of length 83
# Found route of length 85
# Found route of length 93
# Found route of length 79
# Found route of length 79
# Found route of length 89
# Found route of length 115
# Found route of length 109
# Found route of length 115
# Found route of length 109
# Found route of length 99
# Found route of length 101
# Found route of length 129
# Found route of length 97
# Found route of length 89
# Found route of length 79
# Found route of length 91
# Found route of length 109
# Found route of length 71
# Found route of length 133
# Found route of length 105
# Found route of length 129
# Found route of length 79
# Found route of length 109
# Found route of length 135
# Found route of length 81
# Found route of length 89
# Found route of length 79
# Found route of length 85
# Found route of length 79
# Found route of length 93
# Found route of length 87
# Found route of length 81
# Found route of length 97
# Found route of length 75
# Found route of length 77
# Found route of length 77
# Found route of length 141
# Found route of length 73
# Found route of length 105
# Found route of length 87
# Found route of length 115
# Found route of length 77
# Found route of length 71
# Found route of length 115
# Found route of length 111
# Found route of length 109
# Found route of length 81
# Found route of length 89
# Found route of length 79
# Found route of length 89
# Found route of length 73
# Found route of length 79
# Found route of length 103
# Found route of length 91
# Found route of length 101
# Found route of length 77
# Found route of length 79
# Found route of length 1066
# Found route of length 1128
# Found route of length 980
# Found route of length 1016
# Found route of length 1090
# Found route of length 1264
# Found route of length 984
# Found route of length 1188
# Found route of length 1112
# Found route of length 1072
# Found route of length 1118
# Found route of length 918
# Found route of length 1072
# Found route of length 1110
# Found route of length 1012
# Found route of length 1228
# Found route of length 1100
# Found route of length 1032
# Found route of length 1214
# Found route of length 1114
# Found route of length 1214
# Found route of length 960
# Found route of length 1034
# Found route of length 1060
# Found route of length 1040
# Found route of length 974
# Found route of length 974
# Found route of length 1188
# Found route of length 1132
# Found route of length 1230
# Found route of length 1092
# Found route of length 1160
# Found route of length 1050
# Found route of length 1078
# Found route of length 1268
# Found route of length 1066
# Found route of length 1256
# Found route of length 1192
# Found route of length 1026
# Found route of length 1252
# Found route of length 1272
# Found route of length 1016
# Found route of length 1076
# Found route of length 946
# Found route of length 1094
# Found route of length 1056
# Found route of length 914
# Found route of length 1016
# Found route of length 1074
# Found route of length 1032
# Found route of length 1176
# Found route of length 1106
# Found route of length 1164
# Found route of length 1112
# Found route of length 1042
# Found route of length 1234
# Found route of length 1060
# Found route of length 940
# Found route of length 1014
# Found route of length 1018
# Found route of length 1130
# Found route of length 1138
# Found route of length 902
# Found route of length 978
# Found route of length 994
# Found route of length 1010
# Found route of length 1018
# Found route of length 942
# Found route of length 968
# Found route of length 1190
# Found route of length 1118
# Found route of length 1246
# Found route of length 996
# Found route of length 1300
# Found route of length 1160
# Found route of length 1224
# Found route of length 878
# Found route of length 1004
# Found route of length 870
# Found route of length 1146
# Found route of length 1142
# Found route of length 1176
# Found route of length 1032
# Found route of length 978
# Found route of length 1378
# Found route of length 1294
# Found route of length 1004
# Found route of length 952
# Found route of length 1190
# Found route of length 1040
# Found route of length 1004
# Found route of length 1008
# Found route of length 912
# Found route of length 994
# Found route of length 1184
# Found route of length 1026
# Found route of length 1064
# Found route of length 1290
# Found route of length 912
# Found route of length 1160
# Found route of length 1118
# Found route of length 1026
# Found route of length 918
# Found route of length 1158
# Found route of length 934
# Found route of length 970
# Found route of length 1288
# Found route of length 960
# Found route of length 1078
# Found route of length 1088
# Found route of length 1106
# Found route of length 952
# Found route of length 1032
# Found route of length 1058
# Found route of length 982
# Found route of length 1012
# Found route of length 1212
# Found route of length 1128
# Found route of length 966
# Found route of length 1180
# Found route of length 1186
# Found route of length 1098
# Found route of length 982
# Found route of length 1288
# Found route of length 1174
# Found route of length 1046
# Found route of length 1286
# Found route of length 1002
# Found route of length 1218
# Found route of length 992
# Found route of length 1102
# Found route of length 1136
# Found route of length 976
# Found route of length 952
# Found route of length 1166
# Found route of length 1126
# Found route of length 1052
# Found route of length 1106
# Found route of length 1140
# Found route of length 1112
# Found route of length 1192
# Found route of length 1166
# Found route of length 1080
# Found route of length 1214
# Found route of length 952
# Found route of length 860
# Found route of length 872
# Found route of length 978
# Found route of length 1204
# Found route of length 1104
# Found route of length 1034
# Found route of length 998
# Found route of length 1082
# Found route of length 1274
# Found route of length 946
# Found route of length 1228
# Found route of length 1038
# Found route of length 1024
# Found route of length 1114
# Found route of length 1126
# Found route of length 1102
# Found route of length 1202
# Found route of length 870
# Found route of length 1090
# Found route of length 1080
# Found route of length 1032
# Found route of length 1064
# Found route of length 1082
# Found route of length 944
# Found route of length 1170
# Found route of length 1256
# Found route of length 1120
# Found route of length 1082
# Found route of length 1000
# Found route of length 1128
# Found route of length 1106
# Found route of length 1084
# Found route of length 1278
# Found route of length 1118
# Found route of length 954
# Found route of length 1100
# Found route of length 1116
# Found route of length 1038
# Found route of length 1208
# Found route of length 934
# Found route of length 1096
# Found route of length 1080
# Found route of length 930
# Found route of length 1110
# Found route of length 996
# Found route of length 1206
# Found route of length 1136
# Found route of length 1096
# Found route of length 1202
# Found route of length 946
# Found route of length 914
# Found route of length 968
# Found route of length 1100
# Found route of length 1054
# Found route of length 1054
# Found route of length 1040
# Found route of length 1194
# Found route of length 982
# Found route of length 890
# Found route of length 1268
# Found route of length 920
# Found route of length 1150
# Found route of length 1082
# Found route of length 1096
# Found route of length 1044
# Found route of length 932
# Found route of length 952
# Found route of length 1176
# Found route of length 884
# Found route of length 932
# Found route of length 974
# Found route of length 1120
# Found route of length 1196
# Found route of length 930
# Found route of length 1170
# Found route of length 1172
# Found route of length 1162
# Found route of length 1188
# Found route of length 1122
# Found route of length 1064
# Found route of length 984
# Found route of length 984
# Found route of length 1206
# Found route of length 966
# Found route of length 1082
# Found route of length 1322
# Found route of length 1086
# Found route of length 1070
# Found route of length 1178
# Found route of length 1104
# Found route of length 1070
# Found route of length 1050
# Found route of length 1018
# Found route of length 910
# Found route of length 1054
# Found route of length 1116
# Found route of length 1028
# Found route of length 940
# Found route of length 1278
# Found route of length 980
# Found route of length 1256
# Found route of length 1174
# Found route of length 1136
# Found route of length 1260
# Found route of length 962
# Found route of length 1074
# Found route of length 982
# Found route of length 962
# Found route of length 1184
# Found route of length 1048
# Found route of length 918
# Found route of length 986
# Found route of length 1208
# Found route of length 920
# Found route of length 1008
# Found route of length 1252
# Found route of length 970
# Found route of length 962
# Found route of length 1008
# Found route of length 1010
# Found route of length 1012
# Found route of length 964
# Found route of length 1100
# Found route of length 992
# Found route of length 978
# Found route of length 920
# Found route of length 1182
# Found route of length 1102
# Found route of length 942
# Found route of length 1010
# Found route of length 1102
# Found route of length 1088
# Found route of length 1058
# Found route of length 1044
# Found route of length 1004
# Found route of length 1126
# Found route of length 1044
# Found route of length 990
# Found route of length 936
# Found route of length 1210
# Found route of length 1114
# Found route of length 1166
# Found route of length 914
# Found route of length 932
# Found route of length 1124
# Found route of length 922
# Found route of length 858
# Found route of length 1204
# Found route of length 968
# Found route of length 946
# Found route of length 1068
# Found route of length 1224
# Found route of length 936
# Found route of length 1098
# Found route of length 1262
# Found route of length 1030
# Found route of length 1048
# Found route of length 900
# Found route of length 1052
# Found route of length 938
# Found route of length 860
# Found route of length 1140
# Found route of length 1060
# Found route of length 1190
# Found route of length 1098
# Found route of length 994
# Found route of length 1136
# Found route of length 1052
# Found route of length 970
# Found route of length 920
# Found route of length 1070
# Found route of length 912
# Found route of length 904
# Found route of length 1146
# Found route of length 1114
# Found route of length 1060
# Found route of length 1188
# Found route of length 1070
# Found route of length 1036
# Found route of length 1128
# Found route of length 1066
# Found route of length 1124
# Found route of length 1060
# Found route of length 1026
# Found route of length 1022
# Found route of length 978
# Found route of length 1034
# Found route of length 926
# Found route of length 1042
# Found route of length 1062
# Found route of length 996
# Found route of length 936
# Found route of length 1136
# Found route of length 1206
# Found route of length 906
# Found route of length 1200
# Found route of length 1058
# Found route of length 1008
# Found route of length 888
# Found route of length 964
# Found route of length 964
# Found route of length 924
# Found route of length 974
# Found route of length 1150
# Found route of length 898
# Found route of length 1018
# Found route of length 1064
# Found route of length 1058
# Found route of length 1032
# Found route of length 952
# Found route of length 1128
# Found route of length 1206
# Found route of length 970
# Found route of length 1084
# Found route of length 992
# Found route of length 950
# Found route of length 1086
# Found route of length 1162
# Found route of length 908
# Found route of length 1180
# Found route of length 924
# Found route of length 1134
# Found route of length 972
# Found route of length 1134
# Found route of length 1054
# Found route of length 1064
# Found route of length 1192
# Found route of length 978
# Found route of length 1150
# Found route of length 1008
# Found route of length 1156
# Found route of length 1012
# Found route of length 1140
# Found route of length 1250
# Found route of length 1060
# Found route of length 986
# Found route of length 1246
# Found route of length 1038
# Found route of length 960
# Found route of length 1044
# Found route of length 934
# Found route of length 938
# Found route of length 892
# Found route of length 1152
# Found route of length 1240
# Found route of length 1226
# Found route of length 962
# Found route of length 1180
# Found route of length 1292
# Found route of length 932
# Found route of length 1166
# Found route of length 1132
# Found route of length 1100
# Found route of length 984
# Found route of length 1050
# Found route of length 1080
# Found route of length 1250
# Found route of length 942
# Found route of length 1100
# Found route of length 966
# Found route of length 1120
# Found route of length 1120
# Found route of length 988
# Found route of length 938
# Found route of length 924
# Found route of length 1114
# Found route of length 926
# Found route of length 904
# Found route of length 988
# Found route of length 948
# Found route of length 1226
# Found route of length 1124
# Found route of length 900
# Found route of length 1040
# Found route of length 1128
# Found route of length 930
# Found route of length 942
# Found route of length 1004
# Found route of length 1192
# Found route of length 1066
# Found route of length 892
# Found route of length 1072
# Found route of length 1108
# Found route of length 976
# Found route of length 874
# Found route of length 986
# Found route of length 1102
# Found route of length 1114
# Found route of length 1048
# Found route of length 1058
# Found route of length 970
# Found route of length 962
# Found route of length 1118
# Found route of length 1100
# Found route of length 978
# Found route of length 990
# Found route of length 1162
# Found route of length 1050
# Found route of length 1106
# Found route of length 1172
# Found route of length 868
# Found route of length 940
# Found route of length 948
# Found route of length 994
# Found route of length 956
# Found route of length 1124
# Found route of length 1124
# Found route of length 1088
# Found route of length 1006
# Found route of length 914
# Found route of length 1086
# Found route of length 964
# Found route of length 984
# Found route of length 1106
# Found route of length 1068
# Found route of length 1152
# Found route of length 1114
# Found route of length 946
# Found route of length 902
# Found route of length 970
# Found route of length 1146
# Found route of length 934
# Found route of length 1076
# Found route of length 1058
# Found route of length 1106
# Found route of length 990
# Found route of length 992
# Found route of length 942
# Found route of length 1100
# Found route of length 1070
# Found route of length 1022
# Found route of length 1234
# Found route of length 1152
# Found route of length 1116
# Found route of length 1012
# Found route of length 1174
# Found route of length 944
# Found route of length 1014
# Found route of length 1082
# Found route of length 976
# Found route of length 946
# Found route of length 834
# Found route of length 1180
# Found route of length 1128
# Found route of length 1012
# Found route of length 1034
# Found route of length 942
# Found route of length 992
# Found route of length 1048
# Found route of length 1094
# Found route of length 1130
# Found route of length 1110
# Found route of length 1024
# Found route of length 984
# Found route of length 1038
# Found route of length 446
# Found route of length 394
# Found route of length 342
# Found route of length 278
# Found route of length 326
# Found route of length 380
# Found route of length 410
# Found route of length 344
# Found route of length 448
# Found route of length 412
# Found route of length 292
# Found route of length 286
# Found route of length 348
# Found route of length 354
# Found route of length 456
# Found route of length 342
# Found route of length 460
# Found route of length 400
# Found route of length 336
# Found route of length 482
# Found route of length 314
# Found route of length 324
# Found route of length 460
# Found route of length 414
# Found route of length 350
# Found route of length 464
# Found route of length 432
# Found route of length 314
# Found route of length 362
# Found route of length 390
# Found route of length 400
# Found route of length 382
# Found route of length 344
# Found route of length 490
# Found route of length 354
# Found route of length 300
# Found route of length 278
# Found route of length 402
# Found route of length 360
# Found route of length 390
# Found route of length 492
# Found route of length 404
# Found route of length 314
# Found route of length 362
# Found route of length 386
# Found route of length 318
# Found route of length 362
# Found route of length 322
# Found route of length 358
# Found route of length 364
# Found route of length 350
# Found route of length 322
# Found route of length 336
# Found route of length 338
# Found route of length 332
# Found route of length 408
# Found route of length 324
# Found route of length 390
# Found route of length 502
# Found route of length 282
# Found route of length 386
# Found route of length 412
# Found route of length 314
# Found route of length 342
# Found route of length 324
# Found route of length 326
# Found route of length 386
# Found route of length 360
# Found route of length 394
# Found route of length 378
# Found route of length 340
# Found route of length 382
# Found route of length 400
# Found route of length 362
# Found route of length 292
# Found route of length 306
# Found route of length 434
# Found route of length 418
# Found route of length 308
# Found route of length 280
# Found route of length 308
# Found route of length 370
# Found route of length 338
# Found route of length 386
# Found route of length 288
# Found route of length 296
# Found route of length 264
# Found route of length 438
# Found route of length 352
# Found route of length 370
# Found route of length 360
# Found route of length 310
# Found route of length 448
# Found route of length 404
# Found route of length 318
# Found route of length 374
# Found route of length 490
# Found route of length 420
# Found route of length 346
# Found route of length 350
# Found route of length 312
# Found route of length 300
# Found route of length 444
# Found route of length 444
# Found route of length 436
# Found route of length 346
# Found route of length 450
# Found route of length 336
# Found route of length 342
# Found route of length 462
# Found route of length 394
# Found route of length 392
# Found route of length 350
# Found route of length 382
# Found route of length 312
# Found route of length 308
# Found route of length 330
# Found route of length 314
# Found route of length 332
# Found route of length 286
# Found route of length 276
# Found route of length 358
# Found route of length 394
# Found route of length 296
# Found route of length 374
# Found route of length 456
# Found route of length 456
# Found route of length 306
# Found route of length 306
# Found route of length 400
# Found route of length 348
# Found route of length 436
# Found route of length 348
# Found route of length 304
# Found route of length 298
# Found route of length 326
# Found route of length 426
# Found route of length 452
# Found route of length 322
# Found route of length 308
# Found route of length 404
# Found route of length 382
# Found route of length 374
# Found route of length 376
# Found route of length 320
# Found route of length 372
# Found route of length 482
# Found route of length 302
# Found route of length 358
# Found route of length 412
# Found route of length 288
# Found route of length 340
# Found route of length 370
# Found route of length 312
# Found route of length 434
# Found route of length 328
# Found route of length 406
# Found route of length 308
# Found route of length 372
# Found route of length 308
# Found route of length 388
# Found route of length 320
# Found route of length 382
# Found route of length 308
# Found route of length 306
# Found route of length 398
# Found route of length 410
# Found route of length 386
# Found route of length 384
# Found route of length 360
# Found route of length 308
# Found route of length 428
# Found route of length 388
# Found route of length 312
# Found route of length 428
# Found route of length 356
# Found route of length 308
# Found route of length 386
# Found route of length 372
# Found route of length 408
# Found route of length 292
# Found route of length 398
# Found route of length 370
# Found route of length 338
# Found route of length 312
# Found route of length 288
# Found route of length 302
# Found route of length 352
# Found route of length 334
# Found route of length 380
# Found route of length 406
# Found route of length 298
# Found route of length 396
# Found route of length 338
# Found route of length 312
# Found route of length 336
# Found route of length 434
# Found route of length 308
# Found route of length 338
# Found route of length 380
# Found route of length 318
# Found route of length 438
# Found route of length 346
# Found route of length 348
# Found route of length 404
# Found route of length 406
# Found route of length 360
# Found route of length 374
# Found route of length 336
# Found route of length 366
# Found route of length 320
# Found route of length 482
# Found route of length 294
# Found route of length 358
# Found route of length 356
# Found route of length 334
# Found route of length 400
# Found route of length 326
# Found route of length 300
# Found route of length 396
# Found route of length 370
# Found route of length 412
# Found route of length 382
# Found route of length 334
# Found route of length 454
# Found route of length 274
# Found route of length 354
# Found route of length 496
# Found route of length 324
# Found route of length 394
# Found route of length 284
# Found route of length 338
# Found route of length 318
# Found route of length 332
# Found route of length 282
# Found route of length 366
# Found route of length 334
# Found route of length 382
# Found route of length 400
# Found route of length 346
# Found route of length 452
# Found route of length 338
# Found route of length 458
# Found route of length 314
# Found route of length 308
# Found route of length 330
# Found route of length 450
# Found route of length 290
# Found route of length 380
# Found route of length 466
# Found route of length 316
# Found route of length 326
# Found route of length 322
# Found route of length 326
# Found route of length 342
# Found route of length 464
# Found route of length 306
# Found route of length 286
# Found route of length 366
# Found route of length 374
# Found route of length 320
# Found route of length 360
# Found route of length 358
# Found route of length 294
# Found route of length 472
# Found route of length 320
# Found route of length 370
# Found route of length 326
# Found route of length 420
# Found route of length 376
# Found route of length 324
# Found route of length 346
# Found route of length 324
# Found route of length 422
# Found route of length 302
# Found route of length 318
# Found route of length 338
# Found route of length 264
# Found route of length 462
# Found route of length 434
# Found route of length 314
# Found route of length 388
# Found route of length 444
# Found route of length 400
# Found route of length 322
# Found route of length 316
# Found route of length 388
# Found route of length 326
# Found route of length 316
# Found route of length 328
# Found route of length 286
# Found route of length 334
# Found route of length 302
# Found route of length 304
# Found route of length 302
# Found route of length 366
# Found route of length 406
# Found route of length 374
# Found route of length 436
# Found route of length 368
# Found route of length 358
# Found route of length 396
# Found route of length 462
# Found route of length 382
# Found route of length 280
# Found route of length 358
# Found route of length 304
# Found route of length 380
# Found route of length 366
# Found route of length 314
# Found route of length 438
# Found route of length 366
# Found route of length 286
# Found route of length 270
# Found route of length 358
# Found route of length 368
# Found route of length 330
# Found route of length 350
# Found route of length 408
# Found route of length 458
# Found route of length 438
# Found route of length 324
# Found route of length 362
# Found route of length 306
# Found route of length 286
# Found route of length 362
# Found route of length 314
# Found route of length 380
# Found route of length 322
# Found route of length 400
# Found route of length 408
# Found route of length 310
# Found route of length 304
# Found route of length 304
# Found route of length 310
# Found route of length 308
# Found route of length 310
# Found route of length 404
# Found route of length 280
# Found route of length 496
# Found route of length 366
# Found route of length 364
# Found route of length 434
# Found route of length 338
# Found route of length 426
# Found route of length 368
# Found route of length 306
# Found route of length 322
# Found route of length 288
# Found route of length 398
# Found route of length 346
# Found route of length 372
# Found route of length 324
# Found route of length 374
# Found route of length 316
# Found route of length 312
# Found route of length 316
# Found route of length 300
# Found route of length 384
# Found route of length 318
# Found route of length 344
# Found route of length 400
# Found route of length 308
# Found route of length 318
# Found route of length 302
# Found route of length 382
# Found route of length 318
# Found route of length 394
# Found route of length 480
# Found route of length 440
# Found route of length 398
# Found route of length 280
# Found route of length 324
# Found route of length 410
# Found route of length 300
# Found route of length 346
# Found route of length 394
# Found route of length 326
# Found route of length 362
# Found route of length 390
# ...
# Found route of length 719
# Found route of length 553
# Found route of length 631
# Found route of length 655
# Found route of length 541
# Found route of length 673
# Found route of length 615
# Found route of length 657
# Found route of length 545
# Found route of length 583
# Found route of length 567
# Found route of length 599
# Found route of length 639
# Found route of length 621
# Found route of length 785
# Found route of length 551
# Found route of length 577
# Found route of length 1003
# Found route of length 491
# Found route of length 935
# Found route of length 577
# Found route of length 853
# Found route of length 623
# Found route of length 719
# Found route of length 637
# Found route of length 535
# Found route of length 613
# Found route of length 591
# Found route of length 691
# Found route of length 557
# Found route of length 933
# Found route of length 561
# Found route of length 665
# Found route of length 645
# Found route of length 869
# Found route of length 811
# Found route of length 585
# Found route of length 943
# Found route of length 599
# Found route of length 595
# Found route of length 571
# Found route of length 515
# Found route of length 783
# Found route of length 659
# Found route of length 569
# Found route of length 583
# Found route of length 573
# Found route of length 823
# Found route of length 515
# Found route of length 861
# Found route of length 569
# Found route of length 913
# Found route of length 681
# Found route of length 871
# Found route of length 735
# Found route of length 717
# Found route of length 815
# Found route of length 571
# Found route of length 845
# Found route of length 519
# Found route of length 639
# Found route of length 601
# Found route of length 653
# Found route of length 971
# Found route of length 677
# Found route of length 751
# Found route of length 507
# Found route of length 641
# Found route of length 815
# Found route of length 665
# Found route of length 515
# Found route of length 513
# Found route of length 473
# Found route of length 587
# Found route of length 613
# Found route of length 969
# Found route of length 635
# Found route of length 641
# Found route of length 567
# Found route of length 777
# Found route of length 845
# Found route of length 825
# Found route of length 549
# Found route of length 543
# Found route of length 663
# Found route of length 627
# Found route of length 647
# Found route of length 551
# Found route of length 839
# Found route of length 811
# Found route of length 499
# Found route of length 779
# Found route of length 581
# Found route of length 579
# Found route of length 483
# Found route of length 965
# Found route of length 535
# Found route of length 1031
# Found route of length 843
# Found route of length 667
# Found route of length 633
# Found route of length 867
# Found route of length 579
# Found route of length 811
# Found route of length 517
# Found route of length 515
# Found route of length 643
# Found route of length 913
# Found route of length 567
# Found route of length 579
# Found route of length 765
# Found route of length 985
# Found route of length 609
# Found route of length 601
# Found route of length 709
# Found route of length 913
# Found route of length 545
# Found route of length 621
# Found route of length 681
# Found route of length 499
# Found route of length 617
# Found route of length 545
# Found route of length 625
# Found route of length 597
# Found route of length 699
# Found route of length 557
# Found route of length 625
# Found route of length 777
# Found route of length 617
# Found route of length 831
# Found route of length 699
# Found route of length 553
# Found route of length 611
# Found route of length 603
# Found route of length 593
# Found route of length 505
# Found route of length 571
# Found route of length 845
# Found route of length 603
# Found route of length 551
# Found route of length 593
# Found route of length 853
# Found route of length 511
# Found route of length 573
# Found route of length 727
# Found route of length 535
# Found route of length 549
# Found route of length 703
# Found route of length 733
# Found route of length 871
# Found route of length 569
# Found route of length 833
# Found route of length 579
# Found route of length 511
# Found route of length 911
# Found route of length 593
# Found route of length 539
# Found route of length 793
# Found route of length 479
# Found route of length 639
# Found route of length 785
# Found route of length 779
# Found route of length 873
# Found route of length 691
# Found route of length 631
# Found route of length 499
# Found route of length 597
# Found route of length 547
# Found route of length 647
# Found route of length 893
# Found route of length 533
# Found route of length 573
# Found route of length 571
# Found route of length 899
# Found route of length 901
# Found route of length 693
# Found route of length 785
# Found route of length 565
# Found route of length 847
# Found route of length 585
# Found route of length 773
# Found route of length 565
# Found route of length 539
# Found route of length 857
# Found route of length 663
# Found route of length 725
# Found route of length 563
# Found route of length 619
# Found route of length 569
# Found route of length 573
# Found route of length 583
# Found route of length 579
# Found route of length 583
# Found route of length 707
# Found route of length 601
# Found route of length 807
# Found route of length 577
# Found route of length 919
# Found route of length 549
# Found route of length 641
# Found route of length 521
# Found route of length 633
# Found route of length 615
# Found route of length 661
# Found route of length 607
# Found route of length 613
# Found route of length 877
# Found route of length 733
# Found route of length 615
# Found route of length 579
# Found route of length 497
# Found route of length 541
# Found route of length 537
# Found route of length 495
# Found route of length 581
# Found route of length 465
# Found route of length 583
# Found route of length 545
# Found route of length 749
# Found route of length 889
# Found route of length 771
# Found route of length 593
# Found route of length 757
# Found route of length 489
# Found route of length 801
# Found route of length 539
# Found route of length 771
# Found route of length 549
# Found route of length 633
# Found route of length 971
# Found route of length 529
# Found route of length 627
# Found route of length 483
# Found route of length 547
# Found route of length 777
# Found route of length 645
# Found route of length 551
# Found route of length 787
# Found route of length 501
# Found route of length 543
# Found route of length 781
# Found route of length 667
# Found route of length 585
# Found route of length 711
# Found route of length 607
# Found route of length 541
# Found route of length 639
# Found route of length 533
# Found route of length 617
# Found route of length 653
# Found route of length 553
# Found route of length 571
# Found route of length 899
# Found route of length 513
# Found route of length 651
# Found route of length 471
# Found route of length 523
# Found route of length 519
# Found route of length 855
# Found route of length 917
# Found route of length 621
# Found route of length 839
# Found route of length 649
# Found route of length 823
# Found route of length 569
# Found route of length 865
# Found route of length 651
# Found route of length 825
# Found route of length 491
# Found route of length 667
# Found route of length 601
# Found route of length 607
# Found route of length 869
# Found route of length 847
# Found route of length 727
# Found route of length 699
# Found route of length 821
# Found route of length 585
# Found route of length 791
# Found route of length 849
# Found route of length 653
# Found route of length 569
# Found route of length 809
# Found route of length 559
# Found route of length 707
# Found route of length 461
# Found route of length 791
# Found route of length 831
# Found route of length 625
# Found route of length 667
# Found route of length 807
# Found route of length 689
# Found route of length 687
# Found route of length 487
# Found route of length 619
# Found route of length 545
# Found route of length 593
# Found route of length 579
# Found route of length 561
# Found route of length 597
# Found route of length 547
# Found route of length 923
# Found route of length 607
# Found route of length 807
# Found route of length 709
# Found route of length 531
# Found route of length 511
# Found route of length 529
# Found route of length 579
# Found route of length 625
# Found route of length 539
# Found route of length 495
# Found route of length 807
# Found route of length 759
# Found route of length 857
# Found route of length 873
# Found route of length 793
# Found route of length 603
# Found route of length 695
# Found route of length 817
# Found route of length 569
# Found route of length 621
# Found route of length 913
# Found route of length 833
# Found route of length 911
# Found route of length 613
# Found route of length 579
# Found route of length 627
# Found route of length 567
# Found route of length 509
# Found route of length 613
# Found route of length 579
# Found route of length 675
# Found route of length 649
# Found route of length 499
# Found route of length 487
# Found route of length 543
# Found route of length 777
# Found route of length 797
# Found route of length 779
# Found route of length 517
# Found route of length 943
# Found route of length 677
# Found route of length 529
# Found route of length 585
# Found route of length 941
# Found route of length 583
# Found route of length 857
# Found route of length 593
# Found route of length 851
# Found route of length 595
# Found route of length 505
# Found route of length 725
# Found route of length 627
# Found route of length 787
# Found route of length 831
# Found route of length 571
# Found route of length 575
# Found route of length 573
# Found route of length 695
# Found route of length 585
# Found route of length 877
# Found route of length 585
# Found route of length 653
# Found route of length 497
# Found route of length 509
# Found route of length 609
# Found route of length 563
# Found route of length 583
# Found route of length 499
# Found route of length 591
# Found route of length 875
# Found route of length 563
# Found route of length 785
# Found route of length 573
# Found route of length 769
# Found route of length 655
# Found route of length 767
# Found route of length 521
# Found route of length 571
# Found route of length 753
# Found route of length 811
# Found route of length 615
# Found route of length 631
# Found route of length 667
# Found route of length 583
# Found route of length 865
# Found route of length 541
# Found route of length 483
# Found route of length 649
# Found route of length 593
# Found route of length 815
# Found route of length 933
# Found route of length 609
# Found route of length 855
# Found route of length 1255
# Found route of length 1039
# Found route of length 979
# Found route of length 959
# Found route of length 1059
# Found route of length 1177
# Found route of length 849
# Found route of length 891
# Found route of length 961
# Found route of length 849
# Found route of length 923
# Found route of length 885
# Found route of length 1113
# Found route of length 1147
# Found route of length 961
# Found route of length 1059
# Found route of length 955
# Found route of length 1169
# Found route of length 881
# Found route of length 1045
# Found route of length 901
# Found route of length 1015
# Found route of length 829
# Found route of length 973
# Found route of length 887
# Found route of length 899
# Found route of length 887
# Found route of length 915
# Found route of length 1105
# Found route of length 865
# Found route of length 841
# Found route of length 965
# Found route of length 999
# Found route of length 923
# Found route of length 945
# Found route of length 927
# Found route of length 961
# Found route of length 805
# Found route of length 1005
# Found route of length 1153
# Found route of length 863
# Found route of length 935
# Found route of length 949
# Found route of length 881
# Found route of length 991
# Found route of length 853
# Found route of length 917
# Found route of length 1059
# Found route of length 1133
# Found route of length 1093
# Found route of length 1099
# Found route of length 895
# Found route of length 1025
# Found route of length 903
# Found route of length 863
# Found route of length 1031
# Found route of length 1157
# Found route of length 973
# Found route of length 929
# Found route of length 1071
# Found route of length 1117
# Found route of length 835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 19
#      16 aco = AntColonyOptimization(maze, ants_per_gen, generations, q, evaporation)
#      18 # Run optimization and write to file
# ---> 19 tsp_data.calculate_routes(aco)
#      20 tsp_data.write_to_file(persist_file)
#      22 # Read from file and print
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/TSPData.py:30, in TSPData.calculate_routes(self, aco)
#      29 def calculate_routes(self, aco):
# ---> 30     self.product_to_product = self.build_distance_matrix(aco)
#      31     self.start_to_product = self.build_start_to_products(aco)
#      32     self.product_to_end = self.build_products_to_end(aco)
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/TSPData.py:127, in TSPData.build_distance_matrix(self, aco)
#     125         start = self.product_locations[i]
#     126         end = self.product_locations[j]
# --> 127         product_to_product[i].append(aco.find_shortest_route(PathSpecification(start, end)))
#     128 return product_to_product
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/AntColonyOptimization.py:33, in AntColonyOptimization.find_shortest_route(self, path_specification)
#      31 for _ in range(self.ants_per_gen):
#      32     ant = Ant(self.maze, path_specification, self.alpha, self.beta)
# ---> 33     route = ant.find_route()
#      34     route_length = len(route.route)
#      35     ant_routes.append(route)
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Ant.py:19, in Ant.find_route(self)
#      16 visited = {self.start}
#      18 while self.current_position != self.end:
# ---> 19     next_move = self.choose_next_move(visited)
#      20     if next_move is None:
#      21         # No available moves, backtrack
#      22         last_move = route.remove_last()
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Ant.py:35, in Ant.choose_next_move(self, visited)
#      33 def choose_next_move(self, visited):
#      34     pheromone_data = self.maze.get_surrounding_pheromone(self.current_position)
# ---> 35     available_moves = [
#      36         (direction, self.current_position.add_direction(direction))
#      37         for direction, pheromone in pheromone_data.items()
#      38         if self.maze.in_bounds(self.current_position.add_direction(direction)) and self.current_position.add_direction(direction) not in visited and self.maze.is_accessible(self.current_position.add_direction(direction))
#      39     ]
#      41     if not available_moves:
#      42         return None
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Ant.py:38, in <listcomp>(.0)
#      33 def choose_next_move(self, visited):
#      34     pheromone_data = self.maze.get_surrounding_pheromone(self.current_position)
#      35     available_moves = [
#      36         (direction, self.current_position.add_direction(direction))
#      37         for direction, pheromone in pheromone_data.items()
# ---> 38         if self.maze.in_bounds(self.current_position.add_direction(direction)) and self.current_position.add_direction(direction) not in visited and self.maze.is_accessible(self.current_position.add_direction(direction))
#      39     ]
#      41     if not available_moves:
#      42         return None
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Coordinate.py:24, in Coordinate.add_direction(self, dir)
#      23 def add_direction(self, dir):
# ---> 24      return self.add_coordinate(self.dir_to_coordinate_delta(dir))
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Coordinate.py:83, in Coordinate.dir_to_coordinate_delta(self, dir)
#      81 map[Direction.east] = Coordinate(1, 0)
#      82 map[Direction.west] = Coordinate(-1, 0)
# ---> 83 map[Direction.north] = Coordinate(0, -1)
#      84 map[Direction.south] = Coordinate(0, 1)
#      85 return map[dir]
#
# File ~/Documents/Y2/Q3/Computation Intelligence/ACO/src/Coordinate.py:10, in Coordinate.__init__(self, x, y)
#       9 def __init__(self, x, y):
# ---> 10     self.x = x
#      11     self.y = y
#
# KeyboardInterrupt:
