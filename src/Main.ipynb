# %%
import time

from AntColonyOptimization import AntColonyOptimization
from GeneticAlgorithm import GeneticAlgorithm
from Maze import Maze
from PathSpecification import PathSpecification
from TSPData import TSPData

# %% [markdown]
# ### Part 1: The Travelling Robot Problem

# %%
# Please keep your parameters for the Genetic Algorithm easily changeable here
population_size = 200
generations = 200
elite_size = 0.1
mutation_rate = 0.01
persist_file = "./../data/optimal_tsp"

# Setup optimization
tsp_data = TSPData.read_from_file(persist_file)
ga = GeneticAlgorithm(generations, population_size, elite_size, mutation_rate)

# Run optimzation and write to file
solution = ga.solve_tsp(tsp_data)
tsp_data.write_action_file(solution[0], "./../data/tsp_solution.txt")

# %% [markdown]
# ### Part 2: Path Finding Through Ant Colony Optimization

# %%
# Please keep your parameters for the ACO easily changeable here
gen = 30
no_gen = 40
q = 4000
evap = 0.4

# Construct the optimization objects
maze = Maze.create_maze("./../data/hard_maze.txt")
spec = PathSpecification.read_coordinates("./../data/hard_coordinates.txt")
aco = AntColonyOptimization(maze, gen, no_gen, q, evap)

# Save starting time
start_time = int(round(time.time() * 1000))

# Run optimization
shortest_route = aco.find_shortest_route(spec)

# Print time taken
print("Time taken: " + str((int(round(time.time() * 1000)) - start_time) / 1000.0))

# Save solution
shortest_route.write_to_file("./../data/hard_solution.txt")

# Print route size
print("Route size: " + str(shortest_route.size()))
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Found route of length 1143
# Found route of length 1421
# Found route of length 1259
# Found route of length 1291
# Found route of length 1123
# Found route of length 1257
# Found route of length 1333
# Found route of length 1401
# Found route of length 1071
# Found route of length 1101
# Found route of length 1107
# Found route of length 1257
# Found route of length 1333
# Found route of length 1167
# Found route of length 1101
# Found route of length 1057
# Found route of length 1251
# Found route of length 1109
# Found route of length 1039
# Found route of length 1161
# Found route of length 1141
# Found route of length 1299
# Found route of length 1293
# Found route of length 1249
# Found route of length 1097
# Found route of length 1237
# Found route of length 1123
# Found route of length 1185
# Found route of length 1109
# Found route of length 1059
# Found route of length 1175
# Found route of length 1093
# Found route of length 1209
# Found route of length 1137
# Found route of length 1157
# Found route of length 1293
# Found route of length 1249
# Found route of length 1321
# Found route of length 1227
# Found route of length 1029
# Found route of length 1089
# Found route of length 1191
# Found route of length 997
# Found route of length 1197
# Found route of length 1159
# Found route of length 1221
# Found route of length 1281
# Found route of length 1325
# Found route of length 1033
# Found route of length 1063
# Found route of length 1231
# Found route of length 1391
# Found route of length 1115
# Found route of length 1177
# Found route of length 1301
# Found route of length 1079
# Found route of length 1221
# Found route of length 1069
# Found route of length 1321
# Found route of length 1075
# Found route of length 1287
# Found route of length 1075
# Found route of length 1297
# Found route of length 1193
# Found route of length 1201
# Found route of length 1079
# Found route of length 1343
# Found route of length 1119
# Found route of length 1081
# Found route of length 1159
# Found route of length 1263
# Found route of length 1329
# Found route of length 1281
# Found route of length 1203
# Found route of length 1297
# Found route of length 1329
# Found route of length 1183
# Found route of length 1189
# Found route of length 1357
# Found route of length 1333
# Found route of length 1085
# Found route of length 1293
# Found route of length 1279
# Found route of length 1015
# Found route of length 1063
# Found route of length 1221
# Found route of length 1291
# Found route of length 1189
# Found route of length 1243
# Found route of length 1213
# Found route of length 1119
# Found route of length 1175
# Found route of length 1219
# Found route of length 1351
# Found route of length 1249
# Found route of length 1065
# Found route of length 1041
# Found route of length 1031
# Found route of length 1031
# Found route of length 1313
# Found route of length 1195
# Found route of length 1153
# Found route of length 1145
# Found route of length 1271
# Found route of length 1325
# Found route of length 991
# Found route of length 1347
# Found route of length 1289
# Found route of length 1165
# Found route of length 1191
# Found route of length 1231
# Found route of length 1119
# Found route of length 993
# Found route of length 1365
# Found route of length 969
# Found route of length 1315
# Found route of length 1175
# Found route of length 1015
# Found route of length 1149
# Found route of length 1173
# Found route of length 1327
# Found route of length 1337
# Found route of length 1087
# Found route of length 1087
# Found route of length 1023
# Found route of length 1051
# Found route of length 959
# Found route of length 1153
# Found route of length 1083
# Found route of length 1073
# Found route of length 1047
# Found route of length 1293
# Found route of length 1093
# Found route of length 1337
# Found route of length 1257
# Found route of length 1139
# Found route of length 1189
# Found route of length 1039
# Found route of length 993
# Found route of length 1261
# Found route of length 1237
# Found route of length 1313
# Found route of length 1071
# Found route of length 1155
# Found route of length 1329
# Found route of length 979
# Found route of length 1119
# Found route of length 1213
# Found route of length 1149
# Found route of length 1191
# Found route of length 1219
# Found route of length 1221
# Found route of length 1263
# Found route of length 1307
# Found route of length 1333
# Found route of length 1037
# Found route of length 1313
# Found route of length 1129
# Found route of length 1153
# Found route of length 1039
# Found route of length 979
# Found route of length 1175
# Found route of length 1143
# Found route of length 1029
# Found route of length 1117
# Found route of length 1099
# Found route of length 1065
# Found route of length 1057
# Found route of length 925
# Found route of length 999
# Found route of length 1129
# Found route of length 1111
# Found route of length 1279
# Found route of length 1337
# Found route of length 1011
# Found route of length 1149
# Found route of length 1303
# Found route of length 1259
# Found route of length 1139
# Found route of length 1129
# Found route of length 1111
# Found route of length 1119
# Found route of length 1013
# Found route of length 1111
# Found route of length 1117
# Found route of length 1225
# Found route of length 979
# Found route of length 1053
# Found route of length 1253
# Found route of length 1137
# Found route of length 1247
# Found route of length 1165
# Found route of length 1023
# Found route of length 1025
# Found route of length 1031
# Found route of length 1023
# Found route of length 1261
# Found route of length 1243
# Found route of length 1017
# Found route of length 1021
# Found route of length 1175
# Found route of length 1209
# Found route of length 1313
# Found route of length 1049
# Found route of length 1039
# Found route of length 1079
# Found route of length 1401
# Found route of length 1271
# Found route of length 1335
# Found route of length 1251
# Found route of length 1045
# Found route of length 953
# Found route of length 1129
# Found route of length 1125
# Found route of length 1045
# Found route of length 1121
# Found route of length 1001
# Found route of length 1133
# Found route of length 1093
# Found route of length 1139
# Found route of length 957
# Found route of length 1275
# Found route of length 1039
# Found route of length 1099
# Found route of length 1149
# Found route of length 1329
# Found route of length 1053
# Found route of length 1283
# Found route of length 1125
# Found route of length 1263
# Found route of length 1191
# Found route of length 1023
# Found route of length 1191
# Found route of length 937
# Found route of length 1141
# Found route of length 1045
# Found route of length 1367
# Found route of length 1115
# Found route of length 1183
# Found route of length 1207
# Found route of length 1117
# Found route of length 1187
# Found route of length 1175
# Found route of length 1239
# Found route of length 1397
# Found route of length 1041
# Found route of length 1307
# Found route of length 1119
# Found route of length 1217
# Found route of length 1167
# Found route of length 1017
# Found route of length 1137
# Found route of length 1159
# Found route of length 1183
# Found route of length 1177
# Found route of length 977
# Found route of length 1153
# Found route of length 1181
# Found route of length 1285
# Found route of length 1139
# Found route of length 1345
# Found route of length 1111
# Found route of length 1105
# Found route of length 1225
# Found route of length 1227
# Found route of length 1139
# Found route of length 1083
# Found route of length 1011
# Found route of length 1207
# Found route of length 1199
# Found route of length 1175
# Found route of length 1133
# Found route of length 1165
# Found route of length 1059
# Found route of length 1283
# Found route of length 1193
# Found route of length 1337
# Found route of length 1007
# Found route of length 1147
# Found route of length 1061
# Found route of length 1011
# Found route of length 1261
# Found route of length 1285
# Found route of length 1039
# Found route of length 1325
# Found route of length 1333
# Found route of length 1075
# Found route of length 1159
# Found route of length 1037
# Found route of length 1183
# Found route of length 1177
# Found route of length 1215
# Found route of length 1057
# Found route of length 1181
# Found route of length 1165
# Found route of length 1209
# Found route of length 1057
# Found route of length 1269
# Found route of length 1113
# Found route of length 1227
# Found route of length 1381
# Found route of length 1353
# Found route of length 1075
# Found route of length 1127
# Found route of length 1181
# Found route of length 1187
# Found route of length 1119
# Found route of length 1079
# Found route of length 979
# Found route of length 1197
# Found route of length 1157
# Found route of length 1133
# Found route of length 1303
# Found route of length 1171
# Found route of length 1303
# Found route of length 1023
# Found route of length 1139
# Found route of length 1161
# Found route of length 1321
# Found route of length 1143
# Found route of length 1155
# Found route of length 1119
# Found route of length 1183
# Found route of length 1171
# Found route of length 1305
# Found route of length 1139
# Found route of length 1147
# Found route of length 1085
# Found route of length 1237
# Found route of length 1005
# Found route of length 1207
# Found route of length 1083
# Found route of length 1207
# Found route of length 1105
# Found route of length 1121
# Found route of length 1045
# Found route of length 1099
# Found route of length 1055
# Found route of length 1125
# Found route of length 999
# Found route of length 985
# Found route of length 1091
# Found route of length 1073
# Found route of length 927
# Found route of length 993
# Found route of length 1197
# Found route of length 1217
# Found route of length 1185
# Found route of length 1267
# Found route of length 1193
# Found route of length 1273
# Found route of length 969
# Found route of length 1027
# Found route of length 1195
# Found route of length 1059
# Found route of length 1071
# Found route of length 1289
# Found route of length 1241
# Found route of length 1151
# Found route of length 1223
# Found route of length 1175
# Found route of length 1025
# Found route of length 979
# Found route of length 1137
# Found route of length 1115
# Found route of length 1303
# Found route of length 1145
# Found route of length 1209
# Found route of length 1141
# Found route of length 1039
# Found route of length 1045
# Found route of length 1015
# Found route of length 985
# Found route of length 1135
# Found route of length 1283
# Found route of length 1001
# Found route of length 1125
# Found route of length 1063
# Found route of length 1219
# Found route of length 1129
# Found route of length 1201
# Found route of length 1039
# Found route of length 1013
# Found route of length 1015
# Found route of length 1145
# Found route of length 1243
# Found route of length 1333
# Found route of length 1159
# Found route of length 1069
# Found route of length 1243
# Found route of length 1121
# Found route of length 1137
# Found route of length 1197
# Found route of length 1279
# Found route of length 1323
# Found route of length 1173
# Found route of length 1085
# Found route of length 1147
# Found route of length 1179
# Found route of length 1071
# Found route of length 1221
# Found route of length 1161
# Found route of length 1081
# Found route of length 1037
# Found route of length 1345
# Found route of length 1193
# Found route of length 1077
# Found route of length 991
# Found route of length 1139
# Found route of length 1055
# Found route of length 1141
# Found route of length 1259
# Found route of length 1059
# Found route of length 1157
# Found route of length 1133
# Found route of length 1053
# Found route of length 1273
# Found route of length 1025
# Found route of length 1073
# Found route of length 1193
# Found route of length 1053
# Found route of length 1175
# Found route of length 1245
# Found route of length 977
# Found route of length 1189
# Found route of length 991
# Found route of length 1249
# Found route of length 1337
# Found route of length 1289
# Found route of length 1177
# Found route of length 1283
# Found route of length 1231
# Found route of length 1147
# Found route of length 1027
# Found route of length 977
# Found route of length 1295
# Found route of length 1083
# Found route of length 1119
# Found route of length 1375
# Found route of length 1113
# Found route of length 1181
# Found route of length 1113
# Found route of length 1101
# Found route of length 1055
# Found route of length 1169
# Found route of length 1093
# Found route of length 1307
# Found route of length 1151
# Found route of length 1129
# Found route of length 1143
# Found route of length 1157
# Found route of length 1131
# Found route of length 985
# Found route of length 1155
# Found route of length 1063
# Found route of length 1203
# Found route of length 1091
# Found route of length 1143
# Found route of length 1127
# Found route of length 1333
# Found route of length 1319
# Found route of length 1081
# Found route of length 1029
# Found route of length 1219
# Found route of length 1177
# Found route of length 1253
# Found route of length 1199
# Found route of length 1009
# Found route of length 1105
# Found route of length 1025
# Found route of length 1109
# Found route of length 985
# Found route of length 1205
# Found route of length 977
# Found route of length 1037
# Found route of length 963
# Found route of length 1131
# Found route of length 1103
# Found route of length 1051
# Found route of length 1061
# Found route of length 991
# Found route of length 1231
# Found route of length 1011
# Found route of length 1105
# Found route of length 1219
# Found route of length 1279
# Found route of length 1177
# Found route of length 1359
# Found route of length 965
# Found route of length 1299
# Found route of length 1001
# Found route of length 1143
# Found route of length 1303
# Found route of length 1251
# Found route of length 1007
# Found route of length 1225
# Found route of length 1007
# Found route of length 975
# Found route of length 1057
# Found route of length 1059
# Found route of length 1097
# Found route of length 1205
# Found route of length 1159
# Found route of length 1007
# Found route of length 1129
# Found route of length 1023
# Found route of length 1027
# Found route of length 1123
# Found route of length 1251
# Found route of length 1315
# Found route of length 1079
# Found route of length 1087
# Found route of length 1081
# Found route of length 1287
# Found route of length 1291
# Found route of length 1387
# Found route of length 1041
# Found route of length 1073
# Found route of length 1115
# Found route of length 1095
# Found route of length 997
# Found route of length 1037
# Found route of length 1233
# Found route of length 1293
# Found route of length 1361
# Found route of length 1191
# Found route of length 1179
# Found route of length 1125
# Found route of length 1327
# Found route of length 1057
# Found route of length 1169
# Found route of length 1289
# Found route of length 1003
# Found route of length 1013
# Found route of length 1103
# Found route of length 1101
# Found route of length 1295
# Found route of length 1057
# Found route of length 1151
# Found route of length 1231
# Found route of length 975
# Found route of length 1215
# Found route of length 1137
# Found route of length 1075
# Found route of length 1015
# Found route of length 1111
# Found route of length 1131
# Found route of length 1425
# Found route of length 1057
# Found route of length 1193
# Found route of length 1029
# Found route of length 1381
# Found route of length 1151
# Found route of length 1053
# Found route of length 1105
# Found route of length 1153
# Found route of length 1271
# Found route of length 1185
# Found route of length 1095
# Found route of length 1337
# Found route of length 1059
# Found route of length 1033
# Found route of length 1197
# Found route of length 1225
# Found route of length 1117
# Found route of length 1003
# Found route of length 1155
# Found route of length 1133
# Found route of length 1291
# Found route of length 1161
# Found route of length 1179
# Found route of length 1245
# Found route of length 1149
# Found route of length 1277
# Found route of length 1235
# Found route of length 981
# Found route of length 959
# Found route of length 1005
# Found route of length 1149
# Found route of length 1335
# Found route of length 1335
# Found route of length 1039
# Found route of length 1267
# Found route of length 1091
# Found route of length 1229
# Found route of length 1015
# Found route of length 1143
# Found route of length 1045
# Found route of length 1025
# Found route of length 1201
# Found route of length 1151
# Found route of length 961
# Found route of length 935
# Found route of length 989
# Found route of length 1205
# Found route of length 1201
# Found route of length 973
# Found route of length 1153
# Found route of length 1047
# Found route of length 1109
# Found route of length 1227
# Found route of length 1051
# Found route of length 1203
# Found route of length 1171
# Found route of length 1001
# Found route of length 1033
# Found route of length 1135
# Found route of length 1015
# Found route of length 1165
# Found route of length 1071
# Found route of length 1247
# Found route of length 1019
# Found route of length 1121
# Found route of length 1141
# Found route of length 951
# Found route of length 1071
# Found route of length 991
# Found route of length 1085
# Found route of length 1329
# Found route of length 1231
# Found route of length 973
# Found route of length 1303
# Found route of length 1085
# Found route of length 1003
# Found route of length 1333
# Found route of length 1089
# Found route of length 991
# Found route of length 1347
# Found route of length 935
# Found route of length 1103
# Found route of length 1247
# Found route of length 1039
# Found route of length 1023
# Found route of length 1245
# Found route of length 1103
# Found route of length 1303
# Found route of length 1157
# Found route of length 1199
# Found route of length 947
# Found route of length 1045
# Found route of length 909
# Found route of length 1293
# Found route of length 1089
# Found route of length 1261
# Found route of length 1197
# Found route of length 1069
# Found route of length 1143
# Found route of length 1325
# Found route of length 1023
# Found route of length 1145
# Found route of length 1165
# Found route of length 961
# Found route of length 1089
# Found route of length 1011
# Found route of length 1175
# Found route of length 1237
# Found route of length 1087
# Found route of length 1165
# Found route of length 1359
# Found route of length 1143
# Found route of length 1271
# Found route of length 1149
# Found route of length 1037
# Found route of length 1191
# Found route of length 1053
# Found route of length 1089
# Found route of length 1251
# Found route of length 953
# Found route of length 1143
# Found route of length 1185
# Found route of length 1301
# Found route of length 1173
# Found route of length 977
# Found route of length 1037
# Found route of length 1201
# Found route of length 1181
# Found route of length 1005
# Found route of length 1009
# Found route of length 1075
# Found route of length 1103
# Found route of length 1193
# Found route of length 1141
# Found route of length 1229
# Found route of length 1055
# Found route of length 1187
# Found route of length 1295
# Found route of length 1013
# Found route of length 1035
# Found route of length 1085
# Found route of length 1025
# Found route of length 1185
# Found route of length 1303
# Found route of length 1281
# Found route of length 1021
# Found route of length 1025
# Found route of length 1115
# Found route of length 967
# Found route of length 1331
# Found route of length 1031
# Found route of length 1035
# Found route of length 1021
# Found route of length 1329
# Found route of length 1181
# Found route of length 1085
# Found route of length 1101
# Found route of length 1121
# Found route of length 989
# Found route of length 1199
# Found route of length 1161
# Found route of length 1085
# Found route of length 1089
# Found route of length 1259
# Found route of length 1027
# Found route of length 1033
# Found route of length 1061
# Found route of length 1249
# Found route of length 1055
# Found route of length 1033
# Found route of length 971
# Found route of length 1325
# Found route of length 1145
# Found route of length 1113
# Found route of length 1179
# Found route of length 975
# Found route of length 1153
# Found route of length 1021
# Found route of length 1301
# Found route of length 1101
# Found route of length 999
# Found route of length 973
# Found route of length 1039
# Found route of length 1029
# Found route of length 1075
# Found route of length 1095
# Found route of length 1253
# Found route of length 1051
# Found route of length 1261
# Found route of length 1125
# Found route of length 997
# Found route of length 1203
# Found route of length 1021
# Found route of length 1225
# Found route of length 1235
# Found route of length 1037
# Found route of length 1215
# Found route of length 1081
# Found route of length 1181
# Found route of length 1135
# Found route of length 1303
# Found route of length 1287
# Found route of length 1121
# Found route of length 1225
# Found route of length 1057
# Found route of length 983
# Found route of length 1147
# Found route of length 1133
# Found route of length 1075
# Found route of length 1243
# Found route of length 1191
# Found route of length 1027
# Found route of length 1001
# Found route of length 1123
# Found route of length 1069
# Found route of length 1143
# Found route of length 963
# Found route of length 1257
# Found route of length 1063
# Found route of length 941
# Found route of length 1335
# Found route of length 1129
# Found route of length 1129
# Found route of length 1003
# Found route of length 1135
# Found route of length 1261
# Found route of length 1025
# Found route of length 1119
# Found route of length 1041
# Found route of length 1151
# Found route of length 1199
# Found route of length 1215
# Found route of length 1387
# Found route of length 1049
# Found route of length 1009
# Found route of length 1169
# Found route of length 1149
# Found route of length 1055
# Found route of length 1111
# Found route of length 1133
# Found route of length 1113
# Found route of length 1017
# Found route of length 1101
# Found route of length 1143
# Found route of length 1233
# Found route of length 1145
# Found route of length 1311
# Found route of length 1337
# Found route of length 1367
# Found route of length 973
# Found route of length 1019
# Found route of length 1021
# Found route of length 1167
# Found route of length 1165
# Found route of length 1069
# Found route of length 1003
# Found route of length 1015
# Found route of length 1061
# Found route of length 1069
# Found route of length 1297
# Found route of length 1001
# Found route of length 1149
# Found route of length 1317
# Found route of length 981
# Found route of length 1075
# Found route of length 1001
# Found route of length 1005
# Found route of length 1109
# Found route of length 1209
# Found route of length 1053
# Found route of length 1331
# Found route of length 1157
# Found route of length 1143
# Found route of length 1363
# Found route of length 1101
# Found route of length 1045
# Found route of length 967
# Found route of length 1279
# Found route of length 1105
# Found route of length 1159
# Found route of length 1153
# Found route of length 1241
# Found route of length 999
# Found route of length 1117
# Found route of length 955
# Found route of length 991
# Found route of length 1201
# Found route of length 1145
# Found route of length 1157
# Found route of length 1075
# Found route of length 1079
# Found route of length 1085
# Found route of length 1195
# Found route of length 1051
# Found route of length 1167
# Found route of length 997
# Found route of length 1227
# Found route of length 1059
# Found route of length 1091
# Found route of length 1047
# Found route of length 1139
# Found route of length 1041
# Found route of length 1051
# Found route of length 1157
# Found route of length 1279
# Found route of length 1065
# Found route of length 1031
# Found route of length 1069
# Found route of length 1229
# Found route of length 1127
# Found route of length 975
# Found route of length 1029
# Found route of length 1133
# Found route of length 1269
# Found route of length 1143
# Found route of length 1149
# Found route of length 1079
# Found route of length 991
# Found route of length 1089
# Found route of length 1049
# Found route of length 979
# Found route of length 1383
# Found route of length 1153
# Found route of length 1193
# Found route of length 1233
# Found route of length 1073
# Found route of length 1043
# Found route of length 1057
# Found route of length 1015
# Found route of length 1077
# Found route of length 1117
# Found route of length 925
# Found route of length 1147
# Found route of length 1069
# Found route of length 1309
# Found route of length 1349
# Found route of length 1069
# Found route of length 985
# Found route of length 1037
# Found route of length 1163
# Found route of length 1281
# Found route of length 1173
# Found route of length 1183
# Found route of length 1235
# Found route of length 1039
# Found route of length 1105
# Found route of length 1165
# Found route of length 1123
# Found route of length 1147
# Found route of length 1149
# Found route of length 1119
# Found route of length 919
# Found route of length 1073
# Found route of length 1351
# Found route of length 1147
# Found route of length 977
# Found route of length 1171
# Found route of length 1007
# Found route of length 991
# Found route of length 935
# Found route of length 1285
# Found route of length 1137
# Found route of length 1025
# Found route of length 1015
# Found route of length 1319
# Found route of length 1023
# Found route of length 1113
# Found route of length 1067
# Found route of length 1299
# Found route of length 1325
# Found route of length 1257
# Found route of length 1085
# Found route of length 1305
# Found route of length 1229
# Found route of length 1183
# Found route of length 941
# Found route of length 1115
# Found route of length 1179
# Found route of length 1111
# Found route of length 1005
# Found route of length 1087
# Found route of length 1219
# Found route of length 1213
# Found route of length 1131
# Found route of length 1111
# Found route of length 1185
# Found route of length 1017
# Found route of length 1181
# Found route of length 1229
# Found route of length 1309
# Found route of length 1161
# Found route of length 999
# Found route of length 1351
# Found route of length 1317
# Found route of length 989
# Found route of length 1073
# Found route of length 1105
# Found route of length 1151
# Found route of length 1221
# Found route of length 1181
# Found route of length 1163
# Found route of length 1251
# Found route of length 1017
# Found route of length 1001
# Found route of length 1263
# Found route of length 969
# Found route of length 1255
# Found route of length 1161
# Found route of length 1021
# Found route of length 1039
# Found route of length 1163
# Found route of length 1197
# Found route of length 1007
# Found route of length 1165
# Found route of length 1179
# Found route of length 979
# Found route of length 1053
# Found route of length 1183
# Found route of length 993
# Found route of length 1255
# Found route of length 1239
# Found route of length 993
# Found route of length 1075
# Found route of length 959
# Found route of length 1021
# Found route of length 1087
# Found route of length 981
# Found route of length 1035
# Found route of length 995
# Found route of length 993
# Found route of length 1091
# Found route of length 1011
# Found route of length 1003
# Found route of length 987
# Found route of length 1331
# Found route of length 987
# Found route of length 1043
# Found route of length 1015
# Found route of length 1229
# Found route of length 1021
# Found route of length 1089
# Found route of length 1119
# Found route of length 1161
# Found route of length 997
# Found route of length 969
# Found route of length 1015
# Found route of length 1083
# Found route of length 975
# Found route of length 1115
# Found route of length 1197
# Found route of length 1165
# Found route of length 1147
# Found route of length 949
# Found route of length 1377
# Found route of length 1167
# Found route of length 993
# Found route of length 1209
# Found route of length 1033
# Found route of length 1047
# Found route of length 1157
# Found route of length 1001
# Found route of length 1019
# Found route of length 1179
# Found route of length 1119
# Found route of length 993
# Found route of length 1063
# Found route of length 1115
# Found route of length 1121
# Found route of length 1037
# Found route of length 1331
# Found route of length 997
# Found route of length 1019
# Found route of length 1147
# Found route of length 1041
# Found route of length 1057
# Found route of length 1003
# Found route of length 1051
# Found route of length 1033
# Found route of length 1289
# Found route of length 1051
# Found route of length 1123
# Found route of length 1159
# Found route of length 1075
# Found route of length 1081
# Found route of length 967
# Found route of length 1047
# Found route of length 1115
# Found route of length 1037
# Found route of length 1107
# Found route of length 1093
# Found route of length 991
# Found route of length 1125
# Found route of length 1033
# Found route of length 1133
# Found route of length 1187
# Found route of length 1185
# Found route of length 1033
# Found route of length 1069
# Found route of length 1137
# Found route of length 1291
# Found route of length 1211
# Found route of length 941
# Found route of length 987
# Found route of length 1045
# Found route of length 1285
# Found route of length 1127
# Found route of length 1191
# Found route of length 1101
# Found route of length 1117
# Found route of length 989
# Found route of length 1201
# Found route of length 997
# Found route of length 1149
# Found route of length 1101
# Found route of length 1141
# Found route of length 1165
# Found route of length 1003
# Found route of length 1315
# Found route of length 1153
# Found route of length 1065
# Found route of length 1191
# Found route of length 951
# Found route of length 1055
# Found route of length 1071
# Found route of length 1019
# Found route of length 1093
# Found route of length 1165
# Found route of length 1027
# Found route of length 1095
# Found route of length 1041
# Found route of length 1031
# Found route of length 987
# Found route of length 1169
# Found route of length 1245
# Found route of length 1031
# Found route of length 1125
# Found route of length 965
# Found route of length 995
# Found route of length 1217
# Found route of length 1129
# Found route of length 1171
# Found route of length 981
# Found route of length 1011
# Found route of length 1069
# Found route of length 1275
# Found route of length 1199
# Found route of length 1361
# Found route of length 1129
# Found route of length 1091
# Found route of length 1023
# Found route of length 1355
# Found route of length 1077
# Found route of length 961
# Found route of length 1281
# Found route of length 1195
# Found route of length 1259
# Found route of length 1047
# Found route of length 1215
# Found route of length 989
# Found route of length 1285
# Found route of length 1103
# Found route of length 1047
# Found route of length 1105
# Found route of length 1091
# Found route of length 1213
# Found route of length 1031
# Found route of length 1403
# Found route of length 1279
# Found route of length 1045
# Found route of length 1033
# Found route of length 1023
# Found route of length 1155
# Found route of length 1107
# Found route of length 1021
# Found route of length 1117
# Found route of length 1003
# Found route of length 1003
# Found route of length 1157
# Found route of length 981
# Found route of length 1125
# Found route of length 1023
# Found route of length 1123
# Found route of length 1247
# Found route of length 1085
# Found route of length 1013
# Found route of length 1019
# Found route of length 1117
# Found route of length 1009
# Found route of length 1167
# Found route of length 991
# Found route of length 949
# Found route of length 1089
# Found route of length 1053
# Found route of length 1005
# Found route of length 1071
# Found route of length 1059
# Found route of length 1025
# Found route of length 1101
# Found route of length 1099
# Found route of length 1205
# Found route of length 1189
# Found route of length 1007
# Found route of length 983
# Found route of length 1299
# Found route of length 1147
# Found route of length 1169
# Found route of length 1063
# Found route of length 1127
# Found route of length 1155
# Found route of length 1055
# Found route of length 1059
# Found route of length 1115
# Found route of length 1025
# Found route of length 1097
# Found route of length 1005
# Found route of length 1091
# Found route of length 1159
# Found route of length 1217
# Found route of length 1267
# Found route of length 1123
# Found route of length 1115
# Found route of length 1013
# Found route of length 1071
# Found route of length 1165
# Found route of length 1035
# Found route of length 1175
# Found route of length 1017
# Found route of length 1141
# Found route of length 957
# Found route of length 1245
# Found route of length 983
# Found route of length 1279
# Found route of length 1163
# Found route of length 1173
# Found route of length 1053
# Found route of length 1223
# Found route of length 1051
# Found route of length 1039
# Found route of length 1199
# Found route of length 1189
# Found route of length 965
# Found route of length 1279
# Found route of length 1195
# Found route of length 987
# Found route of length 1033
# Found route of length 1159
# Found route of length 1251
# Found route of length 1119
# Found route of length 1171
# Found route of length 965
# Found route of length 1163
# Found route of length 1155
# Time taken: 68.066
# Route size: 909

# %% [markdown]
# ### Synthesis

# %%
# Please keep your parameters for the synthesis part easily changeable here
gen = 1
no_gen = 1
q = 4000
evap = 0.5
elite_size = 0.1
mutation_rate = 0.01

persist_file = "./../data/my_tsp.txt"
tsp_path = "./../data/tsp_products.txt"
coordinates = "./../data/hard_coordinates.txt"

# Construct optimization
maze = Maze.create_maze("./../data/hard_maze.txt")
tsp_data = TSPData.read_specification(coordinates, tsp_path)
aco = AntColonyOptimization(maze, gen, no_gen, q, evap)

# Run optimization and write to file
tsp_data.calculate_routes(aco)
tsp_data.write_to_file(persist_file)

# Read from file and print
tsp_data2 = TSPData.read_from_file(persist_file)
print(tsp_data == tsp_data2)

# Solve TSP using your own paths file
ga = GeneticAlgorithm(generations, population_size, elite_size, mutation_rate)
solution = ga.solve_tsp(tsp_data2)
tsp_data2.write_action_file(solution[0], "./../data/tsp_solution_with_aco.txt")
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Found route of length 0
# Found route of length 83
# Found route of length 1026
# Found route of length 358
# Found route of length 210
# Found route of length 893
# Found route of length 284
# Found route of length 561
# Found route of length 516
# Found route of length 579
# Found route of length 993
# Found route of length 810
# Found route of length 879
# Found route of length 273
# Found route of length 779
# Found route of length 423
# Found route of length 1075
# Found route of length 1103
# Found route of length 79
# Found route of length 0
# Found route of length 1009
# Found route of length 359
# Found route of length 125
# Found route of length 978
# Found route of length 213
# Found route of length 522
# Found route of length 503
# Found route of length 864
# Found route of length 1034
# Found route of length 615
# Found route of length 750
# Found route of length 260
# Found route of length 654
# Found route of length 340
# Found route of length 974
# Found route of length 898
# Found route of length 1242
# Found route of length 919
# Found route of length 0
# Found route of length 900
# Found route of length 898
# Found route of length 227
# Found route of length 878
# Found route of length 687
# Found route of length 802
# Found route of length 529
# Found route of length 113
# Found route of length 356
# Found route of length 293
# Found route of length 795
# Found route of length 339
# Found route of length 807
# Found route of length 183
# Found route of length 601
# Found route of length 402
# Found route of length 347
# Found route of length 1044
# Found route of length 0
# Found route of length 224
# Found route of length 807
# Found route of length 320
# Found route of length 491
# Found route of length 228
# Found route of length 591
# Found route of length 861
# Found route of length 568
# Found route of length 469
# Found route of length 75
# Found route of length 601
# Found route of length 29
# Found route of length 941
# Found route of length 325
# Found route of length 266
# Found route of length 153
# Found route of length 1112
# Found route of length 330
# Found route of length 0
# Found route of length 721
# Found route of length 42
# Found route of length 537
# Found route of length 310
# Found route of length 497
# Found route of length 745
# Found route of length 446
# Found route of length 679
# Found route of length 79
# Found route of length 621
# Found route of length 157
# Found route of length 869
# Found route of length 629
# Found route of length 847
# Found route of length 780
# Found route of length 227
# Found route of length 503
# Found route of length 963
# Found route of length 0
# Found route of length 805
# Found route of length 506
# Found route of length 395
# Found route of length 200
# Found route of length 172
# Found route of length 207
# Found route of length 78
# Found route of length 542
# Found route of length 140
# Found route of length 792
# Found route of length 224
# Found route of length 476
# Found route of length 276
# Found route of length 161
# Found route of length 952
# Found route of length 244
# Found route of length 68
# Found route of length 687
# Found route of length 0
# Found route of length 517
# Found route of length 366
# Found route of length 623
# Found route of length 991
# Found route of length 440
# Found route of length 609
# Found route of length 79
# Found route of length 663
# Found route of length 137
# Found route of length 883
# Found route of length 491
# Found route of length 675
# Found route of length 624
# Found route of length 799
# Found route of length 811
# Found route of length 713
# Found route of length 610
# Found route of length 473
# Found route of length 0
# Found route of length 217
# Found route of length 130
# Found route of length 592
# Found route of length 189
# Found route of length 480
# Found route of length 418
# Found route of length 138
# Found route of length 324
# Found route of length 666
# Found route of length 68
# Found route of length 566
# Found route of length 419
# Found route of length 468
# Found route of length 262
# Found route of length 322
# Found route of length 431
# Found route of length 402
# Found route of length 143
# Found route of length 0
# Found route of length 363
# Found route of length 631
# Found route of length 206
# Found route of length 257
# Found route of length 225
# Found route of length 103
# Found route of length 255
# Found route of length 791
# Found route of length 229
# Found route of length 503
# Found route of length 586
# Found route of length 725
# Found route of length 411
# Found route of length 711
# Found route of length 232
# Found route of length 469
# Found route of length 378
# Found route of length 165
# Found route of length 0
# Found route of length 572
# Found route of length 45
# Found route of length 458
# Found route of length 382
# Found route of length 100
# Found route of length 464
# Found route of length 528
# Found route of length 174
# Found route of length 1035
# Found route of length 1096
# Found route of length 143
# Found route of length 655
# Found route of length 1041
# Found route of length 130
# Found route of length 819
# Found route of length 724
# Found route of length 623
# Found route of length 304
# Found route of length 0
# Found route of length 297
# Found route of length 176
# Found route of length 752
# Found route of length 286
# Found route of length 846
# Found route of length 220
# Found route of length 632
# Found route of length 714
# Found route of length 873
# Found route of length 706
# Found route of length 596
# Found route of length 564
# Found route of length 257
# Found route of length 614
# Found route of length 351
# Found route of length 412
# Found route of length 133
# Found route of length 249
# Found route of length 0
# Found route of length 115
# Found route of length 529
# Found route of length 33
# Found route of length 485
# Found route of length 415
# Found route of length 287
# Found route of length 747
# Found route of length 680
# Found route of length 291
# Found route of length 497
# Found route of length 669
# Found route of length 74
# Found route of length 899
# Found route of length 532
# Found route of length 305
# Found route of length 478
# Found route of length 210
# Found route of length 63
# Found route of length 0
# Found route of length 496
# Found route of length 352
# Found route of length 536
# Found route of length 300
# Found route of length 422
# Found route of length 227
# Found route of length 178
# Found route of length 895
# Found route of length 157
# Found route of length 95
# Found route of length 698
# Found route of length 137
# Found route of length 470
# Found route of length 243
# Found route of length 346
# Found route of length 746
# Found route of length 383
# Found route of length 532
# Found route of length 0
# Found route of length 356
# Found route of length 144
# Found route of length 876
# Found route of length 556
# Found route of length 771
# Found route of length 690
# Found route of length 439
# Found route of length 623
# Found route of length 541
# Found route of length 566
# Found route of length 645
# Found route of length 322
# Found route of length 349
# Found route of length 236
# Found route of length 352
# Found route of length 45
# Found route of length 518
# Found route of length 554
# Found route of length 0
# Found route of length 288
# Found route of length 434
# Found route of length 208
# Found route of length 401
# Found route of length 284
# Found route of length 829
# Found route of length 79
# Found route of length 227
# Found route of length 458
# Found route of length 259
# Found route of length 456
# Found route of length 185
# Found route of length 564
# Found route of length 744
# Found route of length 475
# Found route of length 604
# Found route of length 108
# Found route of length 478
# Found route of length 0
# Found route of length 740
# Found route of length 408
# Found route of length 1013
# Found route of length 1088
# Found route of length 325
# Found route of length 955
# Found route of length 1045
# Found route of length 222
# Found route of length 1109
# Found route of length 630
# Found route of length 599
# Found route of length 686
# Found route of length 210
# Found route of length 363
# Found route of length 302
# Found route of length 736
# Found route of length 424
# Found route of length 834
# Found route of length 0
# Found route of length 818
# Found route of length 643
# Found route of length 856
# Found route of length 487
# Found route of length 755
# Found route of length 521
# Found route of length 550
# Found route of length 545
# Found route of length 42
# Found route of length 205
# Found route of length 482
# Found route of length 544
# Found route of length 345
# Found route of length 238
# Found route of length 730
# Found route of length 352
# Found route of length 466
# Found route of length 680
# Found route of length 0
# Found route of length 59
# Found route of length 70
# Found route of length 961
# Found route of length 315
# Found route of length 145
# Found route of length 808
# Found route of length 183
# Found route of length 632
# Found route of length 533
# Found route of length 548
# Found route of length 878
# Found route of length 603
# Found route of length 966
# Found route of length 214
# Found route of length 838
# Found route of length 314
# Found route of length 980
# Found route of length 732
# Found route of length 1124
# Found route of length 1141
# Found route of length 414
# Found route of length 1042
# Found route of length 1102
# Found route of length 347
# Found route of length 998
# Found route of length 797
# Found route of length 692
# Found route of length 795
# Found route of length 373
# Found route of length 848
# Found route of length 445
# Found route of length 1131
# Found route of length 481
# Found route of length 1077
# Found route of length 133
# Found route of length 719
# True
